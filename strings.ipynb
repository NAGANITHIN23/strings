# %%
'Hello'
# Out:
# 'Hello'

# %%
'I am nitin'
# Out:
# 'I am nitin'

# %%
'These are called strings'
# Out:
# 'These are called strings'

# %%
'Now we'll be seeing error here'
# Out:
#   File "<ipython-input-4-9a56c7384a82>", line 1
#     'Now we'll be seeing error here'
#             ^
# SyntaxError: invalid syntax

# %%
"Now we'll see the valid syntax"
# Out:
# "Now we'll see the valid syntax"

# %%
print('naruto')
print('sasuke')
# Out:
# naruto
# sasuke

# %%
print('are the best rivals')
print('\n')
print('after hashirama and madara')
# Out:
# are the best rivals
#
#
# after hashirama and madara

# %%
len('eren jeager')
# Out:
# 11

# %%
s = 'Nitin hiro'

# %%
s
# Out:
# 'Nitin hiro'

# %%
s[0]
# Out:
# 'N'

# %%
s[1]
# Out:
# 'i'

# %%
s[1:]
# Out:
# 'itin hiro'

# %%
s[:3]
# Out:
# 'Nit'

# %%
s[:]
# Out:
# 'Nitin hiro'

# %%
s[-1]
# Out:
# 'o'

# %%
s[:-1]
# Out:
# 'Nitin hir'

# %%
s[:-3]
# Out:
# 'Nitin h'

# %%
s[::1]
# Out:
# 'Nitin hiro'

# %%
s[::-1]
# Out:
# 'orih nitiN'

# %%
s
# Out:
# 'Nitin hiro'

# %%
s + ' and naruto'
# Out:
# 'Nitin hiro and naruto'

# %%
s = s + ' and naruto'

# %%
print(s)
# Out:
# Nitin hiro and naruto

# %%
number = '6'

# %%
number*9
# Out:
# '666666666'

# %%
s.upper()
# Out:
# 'NITIN HIRO AND NARUTO'

# %%
s.lower()
# Out:
# 'nitin hiro and naruto'

# %%
s.split()
# Out:
# ['Nitin', 'hiro', 'and', 'naruto']

# %%
s.find('n')
# Out:
# 4

# %%
s.count('n')
# Out:
# 3

# %%
'Atack on titan: {}'.format('isayama')
# Out:
# 'Atack on titan: isayama'
